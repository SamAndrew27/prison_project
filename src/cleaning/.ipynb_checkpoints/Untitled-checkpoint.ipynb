# %%
import pandas as pd

# %%
from cleaning_second_half import clean_all_second_half
from cleaning_first_half import clean_all_first_half, load_data_or_legend
from join_years import load_all_years

df_1 = clean_all_first_half()
df_2 = clean_all_second_half()
df = load_all_years()

# %%
df
# Out:
#               term                crime     race       nativity  year  \
# 0            [4.5]            [Larceny]    White  United States  1878
# 1            [1.5]            [Forgery]    White  United States  1878
# 2           [Life]             [Murder]    White  United States  1878
# 3            [8.0]            [Larceny]    White         Canada  1878
# 4            [3.0]            [Larceny]  Mexican  United States  1878
# ...            ...                  ...      ...            ...   ...
# 1608    [1.0, 3.0]            [Forgery]    Black          Black  1900
# 1609    [2.0, 5.0]            [Larceny]    Black          Black  1900
# 1610    [4.0, 6.0]            [Larceny]    White  United States  1900
# 1611    [1.0, 2.0]  [Burglary, Larceny]    Black          Black  1900
# 1612  [20.0, 25.0]             [Murder]    White        Austria  1900
#
#      max_term min_term
# 0         4.5      4.5
# 1         1.5      1.5
# 2        Life     Life
# 3           8        8
# 4           3        3
# ...       ...      ...
# 1608        3        1
# 1609        5        2
# 1610        6        4
# 1611        2        1
# 1612       25       20
#
# [3068 rows x 7 columns]

# %%
result = set()
for idx, row in df.iterrows():
    for elem in row['crime']:
        result.add(elem)
result
# Out:
# {'Abortion',
#  'Administering Poison',
#  'Arson',
#  'Assault',
#  'Assault to Ravish',
#  'Assault w/ Intent to Kill',
#  'Assault w/ Intent to Murder',
#  'Assault w/ Intent to Rape',
#  'Assault w/ Intent to Rob',
#  'Assisting to Kill',
#  'Assisting to Murder',
#  'Attempt to Rob',
#  'Attempted Arson',
#  'Attempted Murder',
#  'Attempted Robbery',
#  'Bigamy',
#  'Buggary',
#  'Burglary',
#  'Cheat',
#  'Confidence Games',
#  'Conspiracy',
#  'Conspiring to Murder',
#  'Counterfeiting',
#  'Crime Against Nature',
#  'Defacing Brands',
#  'Effacing and Defacing Brands',
#  'Embezzlement',
#  'False Imp',
#  'False Pretenses',
#  'Felonious Assault',
#  'Felony',
#  'Felony, Branding Stock',
#  'Forgery',
#  'Grand Larceny',
#  'Having Burgular Tools',
#  'Having Ficticious Checks',
#  'Having Tools with Intent to Commit Burglary',
#  'Having Tools with Intent to Enter Building',
#  'Illegal Voting',
#  'Incest',
#  'Kidnapping',
#  'Killing Cattle',
#  'Killing Stock',
#  'Larceny',
#  'Larceny as Bailee',
#  'Larceny from Person',
#  'Malicious Mischief',
#  'Maliciously Destroying Check',
#  'Manslaughter',
#  'Mayhem',
#  'Murder',
#  'Obstructing of Railroad Track',
#  'Perjury',
#  'Rape',
#  'Receiving Stolen Goods',
#  'Rescue of Prisoner',
#  'Robbery',
#  'Sodomy',
#  'Stealing / Killing Cattle',
#  'Stealing Stock',
#  'Train Wrecking',
#  'Using Instruments with Intent to Commit Abortion',
#  'Uttering',
#  'Uttering Forgery',
#  'Voluntary Manslaughter'}

# %% [markdown]
# ### Columns to look at:
# term
# nativity
# crime
# race

# %%
result = []
for idx, row in df.iterrows():
    lst = row['term']
    for elem in lst:
        result.add(elem)
# Out:
# [['Larceny', 'Bigamy'],
#  ['Larceny', 'Burglary'],
#  ['Larceny', 'Assault'],
#  ['Burglary', 'Larceny', 'Assault'],
#  ['False Imp', 'Larceny', 'Assault w/ Intent to Murder'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Bigamy'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny', 'Assault w/ Intent to Kill'],
#  ['Larceny', 'Forgery'],
#  ['Larceny', 'Assault w/ Intent to Murder'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Grand Larceny', 'Assault w/ Intent to Kill'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Larceny'],
#  ['Larceny', 'Assault w/ Intent to Murder'],
#  ['Assault w/ Intent to Kill', 'Assault w/ Intent to Rob'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Robbery', 'Larceny as Bailee'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['False Pretenses', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Murder', 'Manslaughter'],
#  ['Larceny', 'Assault w/ Intent to Kill'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Robbery'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering Forgery'],
#  ['Forgery', 'Uttering Forgery'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Larceny', 'Assault'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Confidence Games'],
#  ['Larceny', 'Confidence Games'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Sodomy', 'Buggary'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Confidence Games'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Robbery'],
#  ['Larceny', 'Assault'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Forgery', 'Uttering'],
#  ['Forgery', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Robbery', 'Larceny'],
#  ['Robbery', 'Larceny'],
#  ['Forgery', 'False Pretenses'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'False Pretenses'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'False Pretenses'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Arson', 'Effacing and Defacing Brands'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering Forgery'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Robbery', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'False Pretenses'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Arson', 'Defacing Brands'],
#  ['Burglary', 'Larceny'],
#  ['Robbery', 'Assault w/ Intent to Rob'],
#  ['Burglary', 'Larceny'],
#  ['Murder', 'Attempted Murder'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering'],
#  ['Robbery', 'Attempted Robbery'],
#  ['Assault w/ Intent to Kill', 'Assault w/ Intent to Rob'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Robbery', 'Assault w/ Intent to Rob'],
#  ['Robbery', 'Attempted Robbery'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Robbery'],
#  ['Larceny', 'Robbery'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny', 'Receiving Stolen Goods'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Having Burgular Tools'],
#  ['Burglary', 'Robbery'],
#  ['Burglary', 'Robbery'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Robbery'],
#  ['Embezzlement', 'Forgery'],
#  ['Forgery', 'Uttering'],
#  ['Forgery', 'Uttering'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering', 'Having Ficticious Checks'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Uttering', 'Forgery'],
#  ['Burglary', 'Larceny'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Rape', 'Incest'],
#  ['Forgery', 'Uttering'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Larceny', 'Receiving Stolen Goods'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Incest', 'Rape'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Incest', 'Rape'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Rape', 'Incest'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny'],
#  ['Burglary', 'Larceny']]

# %%
df_2.race.unique()
# Out:
# array(['White', 'Black', 'Mexican', '?', 'Asian'], dtype=object)

# %%
legend = load_data_or_legend(False)
states = list(legend['State Names'].dropna())
states
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'Arkansas',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Mississippi',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Puerto Rico',
#  'Rhode Island',
#  'South Carolina',
#  'South Dakota',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Virgin Islands',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming']

# %%
df_total = pd.concat([df_1, df_2])
df_total.info()
# Out:
# array(['Massachusetts', 'District of Columbia', 'Pennsylvania', 'Canada',
#        'California', 'Italy', 'Kentucky', 'England', 'Ohio', 'Iowa',
#        'New York', 'Missouri', 'Maryland', 'Illinois', 'Wisconsin',
#        'Ireland', 'Germany', 'France', 'Louisiana', 'Indiana', 'Michigan',
#        'Minnesota', 'Alabama', 'Virginia', 'Austria', 'New Mexico',
#        'Mexico', 'Kansas', 'Georgia', 'Indian Territory', 'Texas',
#        'Prussia', 'North Carolina', 'Isle of Man', 'Nebraska',
#        'Tennessee', 'Saxony', 'Vermont', 'South Carolina', 'Maine',
#        'Mississippi', 'New Jersey', 'Nova Scotia', 'Bohemia',
#        'Connecticut', 'Rhode Island', 'Colorado', 'West Virginia',
#        'Russia', 'Scotland', 'Switzerland', 'Cuba', 'Australia', 'Utah',
#        'Sweden', 'Florida', 'Norway', 'Arkansas', 'Arizona',
#        "Prince Edward's Island", 'Wyoming', 'Oregon', 'New Hampshire',
#        'Hungary', 'China', 'Denmark', 'Alsace', 'Wales', 'Alaska',
#        'Montana', 'Poland', 'Delaware', 'On the Sea', 'East Indies'],
#       dtype=object)

# %%
df_1.clean_race.unique()
# Out:
# array(['White', 'Mexican', 'Black', 'Mulatto', 'Indian', 'Mongolian'],
#       dtype=object)

# %%
mex_df = df_1[df_1['clean_race']=='Indian Territory']

# %%
mex_df.clean_nativity.value_counts()
# Out:
# New Mexico    22
# Colorado       8
# Mexico         2
# Arizona        1
# Ireland        1
# California     1
# Name: clean_nativity, dtype: int64

# %%
len(mex_df)
# Out:
# 35
